# %%
import pyabf
import matplotlib.pyplot as plt
import numpy as np
#from matplotlib import cm
#from matplotlib.colors import ListedColormap, LinearSegmentedColormap
from os import getcwd,listdir
#import csv
from util import findStable_Bias, print_points_qty, plot_wave, plot_colormap, calculate_mean

# %% [markdown]
# # Start

# %% [markdown]
# ##### V2: Include Bias
# * 800mV 22214004.abf: 3120 + 4(start) + 3(end) = 3127
# * 700mV 22214005.abf: 3120 + 6(start) = 3126
# * 200mV 22318006.abf: 3120 + 5(start) = 3125
# * 500mV 22304010.abf:
# * 200mV 22323007.abf: 3120 +
# * 200mV 22504024.abf: 3120 + 12(start) = 3132
# * 600mV 22519010.abf: 3120 + 3(start)= 3123 #Care for time: 36818519 36818524
# ### V1: Not include Bias
#
# * 800mV 21n05000.abf: 3120 + 4(start) = 3124
# * 700mV 21n05001.abf: 3120 + 4(start) + 41(end) = 3165
# * 600mV 21n05002.abf: 3120 + 4(start) = 3124
# * 500mV 21n05003.abf: 3120 + 6(start) + 21(end) = 3147
# * 400mV 21n05004.abf: Last point have only close, 3120+5(start)+1(end) = 3126
# * 300mV 21n05005.abf: 3120 + 4(start) + 39(end) = 3163
# * 600mV 21930014.abf: 3120 + 5(start)  = 3125
# * 800mV 21d04000.abf: 3120 + 6(start) + 30(end) =3156

# %%
mat = [[1,2,3],[4,5,6],[7,8]]
mat[1:][:]
# Out:
# [[4, 5, 6], [7, 8]]

# %%
mat = [1,2,3,4,5]
mat[:-0]
# Out:
# []

# %%
abfFile = "24903000.abf"
abf = pyabf.ABF("abf\\"+abfFile)

# %%
bins = 50
# start_ignore and end_ignore: extra points before reshape into rows
# start_extra and end_extra: extra points of each rows
start_ignore = 2 #Don't include the single point
end_ignore = 12  #Don't include the single point
start_extra = 5
end_extra = 0
volt = 200
title_prefix = str(volt)+"mV"
fig_save_path =getcwd()+"\\result\\"
Row = 100
Col = 100
start_single = True
end_single = False
emf_bias = -300
current_bias = 0

# %%
ignore = (start_ignore,end_ignore)
extra = (start_extra,end_extra)
dim = (Row-1, Col)
single = (start_single,end_single)

# %%
close,far,close_index,end_index = findStable_Bias(abf,volt,single=single)
# Out:
# Close point found: 11009
# Far point found: 11009

# %%
plt.figure()
plt.hist((close,far),bins=bins,label = ('EMF close','EMF far'),color = ('red','blue'))
plt.legend()
plt.title("%s mean histogram"%(title_prefix))
plt.savefig("%s mean histogram"%(title_prefix))
plt.show()

# %%
target = close/far
target = calculate_mean(target)
#mean = np.mean(target)
#std = np.std(target)
#print(f"%lf ± %lf" %(mean,std))
target = target.reshape(Row,Col)
plot_colormap(target,title = title_prefix + " EMF close÷far",path = fig_save_path)
# Out:
# 1.388238 ± 0.274383
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21900\1084122144.py in <module>
#       3 std = np.std(target)
#       4 print(f"%lf ± %lf" %(mean,std))
# ----> 5 target = target.reshape(Row,Col)
#       6 plot_colormap(target,title = title_prefix + " EMF close÷far",path = fig_save_path)
#
# ValueError: cannot reshape array of size 11009 into shape (100,100)

# %%
target = close-far
mean = np.mean(target)
std = np.std(target)
print(f"%lf ± %lf" %(mean,std))
target = target.reshape(Row,Col)

plot_colormap(target,title = title_prefix + " EMF close-far“ ,path = fig_save_path)

# %%
# Calculate on Current
I_close,I_far,_,_ = findStable_Bias(abf,volt,start_single=start_single,end_single=end_single,channel = 0)
# Out:
# Close point found: 1998
# Far point found: 1998
# 243 None
# 243 None

# %%
plt.figure()
plt.hist((I_close,I_far),bins=bins,label = ('Current close','Current far'))
plt.legend()
plt.title(title_prefix + " Current histogram" )
plt.savefig(fig_save_path+title_prefix + " Current histogram")
plt.show()

# %%
I_aut = I_aut_close/I_aut_far
I_quartz = I_quartz_close/I_quartz_far

# %%
plt.figure()
plt.hist((I_aut,I_quartz),bins=bins,label = ('AUT','QUARTZ'),color = ('red','blue'))
plt.legend()
plt.title(title_prefix + " mean,Current close/Current far histogram-pqty =" +str(pqty))
plt.savefig(fig_save_path+title_prefix + " mean,Current close divide Current far histogram-pqty =" +str(pqty))
plt.show()

# %%
a = I_aut
mean = np.mean(a)
Max = np.max(a)
Min = np.min(a)
print("AUT: %lf +- %lf" %(mean,max(Max-mean,mean-Min)))
a = I_quartz
mean = np.mean(a)
Max = np.max(a)
Min = np.min(a)
print("QUARTZ: %lf +- %lf" %(mean,max(Max-mean,mean-Min)))

I_aut = np.reshape(I_aut,(Row-1,pqty))
I_quartz = np.reshape(I_quartz,(Row-1,pqty))

Current_normalized_data = np.hstack((I_aut,I_quartz))

plot_colormap(Current_normalized_data,title = title_prefix +  " Current close divide far-pqty =" +str(pqty),path = fig_save_path)
# Out:
# AUT: 0.967850 +- 0.060035
# QUARTZ: 0.968635 +- 0.052033
# 40 39

# %%
I_aut = I_aut_close-I_aut_far
I_quartz = I_quartz_close-I_quartz_far

a = I_aut
mean = np.mean(a)
Max = np.max(a)
Min = np.min(a)
print("AUT: %lf +- %lf" %(mean,max(Max-mean,mean-Min)))
a = I_quartz
mean = np.mean(a)
Max = np.max(a)
Min = np.min(a)
print("QUARTZ: %lf +- %lf" %(mean,max(Max-mean,mean-Min)))

I_aut = np.reshape(I_aut,(Row-1,pqty))
I_quartz = np.reshape(I_quartz,(Row-1,pqty))

Current_normalized_data_subs = np.hstack((I_aut,I_quartz))

plot_colormap(Current_normalized_data_subs,title = title_prefix +  " Current close - far-pqty =" +str(pqty),path = fig_save_path)
# Out:
# AUT: 0.061598 +- 0.120897
# QUARTZ: 0.060227 +- 0.099411
# 40 39

# %%
with open("result\\"+abfFile+'_current_div-pqty='+str(pqty)+'.csv', 'w', encoding='UTF8', newline='') as f:
    writer = csv.writer(f)

    # write the data
    for row in Current_normalized_data:
        writer.writerow(row)

# %%
with open("result\\"+abfFile+'_current_subs-pqty='+str(pqty)+'.csv', 'w', encoding='UTF8', newline='') as f:
    writer = csv.writer(f)

    # write the data
    for row in Current_normalized_data_subs:
        writer.writerow(row)

# %%
with open("result\\"+abfFile+'_EMF_div-pqty='+str(pqty)+'.csv', 'w', encoding='UTF8', newline='') as f:
    writer = csv.writer(f)

    # write the data
    for row in EMF_normalized_data:
        writer.writerow(row)

# %%
with open("result\\"+abfFile+'_EMF_subs-pqty='+str(pqty)+'.csv', 'w', encoding='UTF8', newline='') as f:
    writer = csv.writer(f)

    # write the data
    for row in EMF_normalized_data_subs:
        writer.writerow(row)

# %%
with open("result\\"+abfFile+'_EMF-pqty='+str(pqty)+'.csv', 'w', encoding='UTF8', newline='') as f:
    writer = csv.writer(f)

    # write the data
    for w,x,y,z in zip(aut_close,aut_far,quartz_close,quartz_far):
        writer.writerow([w,x,y,z])

# %%
with open("result\\"+abfFile+'-pqty='+str(pqty)+'_current.csv', 'w', encoding='UTF8', newline='') as f:
    writer = csv.writer(f)

    # write the data
    for w,x,y,z in zip(I_aut_close,I_aut_far,I_quartz_close,I_quartz_far):
        writer.writerow([w,x,y,z])

# %%
with open("result\\"+abfFile+'_EMF_close-pqty='+str(pqty)+'.csv', 'w', encoding='UTF8', newline='') as f:
    writer = csv.writer(f)

    # write the data
    w_close = np.hstack((np.reshape(aut_close,(Row-1,int(Col/2))),np.reshape(quartz_close,(Row-1,int(Col/2)))))
    for x in w_close:
        writer.writerow(x)

# %%
with open("result\\"+abfFile+'_EMF_far-pqty='+str(pqty)+'.csv', 'w', encoding='UTF8', newline='') as f:
    writer = csv.writer(f)

    # write the data
    w_far = np.hstack((np.reshape(aut_far,(Row-1,int(Col/2))),np.reshape(quartz_far,(Row-1,int(Col/2)))))
    for x in w_far:
        writer.writerow(x)

# %% [markdown]
# # Test

# %% [markdown]
# ## Test 01 -- With start time and end time

# %%
timeStart = 0
timeEnd = 20000
plot_wave(abf,volt,timeStart = timeStart, timeEnd = timeEnd,channel=4)
print(abf.sweepY[timeStart:timeEnd])
# Out:
# Close point found: 2
# Far point found: 1
# [216.543  216.543  216.4819 ... 216.4819 216.4819 216.4819]

# %%
#Test
abfFile = "23428006.abf"
volt = 500
abf = pyabf.ABF("..\\data\\0727\\23428006\\"+abfFile)
plot_v2(abf,volt,timeStart = 0,timeEnd = 4000,channel=2)
plot_v2(abf,volt,timeStart = 0 ,timeEnd = 4000,channel=4)
# Out:
# Close point found: 1
# Far point found: 0
# Close point found: 1
# Far point found: 0
# (1, 0)

# %% [markdown]
# ## Test 02_v2 -- Check all graph

# %%
interval = 200000
for i in range(0,len(abf.sweepY),interval):
    print("Time: %d ~ %d"%(i,i+interval+50))
    timeStart = i
    timeEnd = i+interval+50
    close_qty,far_qty = plot_v2(abf,volt,timeStart = timeStart, timeEnd = timeEnd,channel = 4)
# Out:
# Time: 0 ~ 200050
# Close point found: 10
# Far point found: 9
# Time: 200000 ~ 400050
# Close point found: 11
# Far point found: 11
# Time: 400000 ~ 600050
# Close point found: 7
# Far point found: 7
# Time: 600000 ~ 800050
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10764\3836531915.py in <module>
#       4     timeStart = i
#       5     timeEnd = i+interval+50
# ----> 6     close_qty,far_qty = plot_v2(abf,volt,timeStart = timeStart, timeEnd = timeEnd,channel = 4)
#       7
#
# ~\AppData\Local\Temp\ipykernel_10764\694355240.py in plot_v2(abf, volt, start_single, end_single, timeStart, timeEnd, channel)
#       5
#       6     #plot the stable
# ----> 7     index,close_index,far_index = analysis_Bias(abf,volt,start_single,end_single,timeStart = timeStart,timeEnd = timeEnd)
#       8     abf.setSweep(0,channel = channel)
#       9     barX_start = []
#
# ~\AppData\Local\Temp\ipykernel_10764\4058311495.py in analysis_Bias(abf, volt, start_single, end_single, timeStart, timeEnd)
#       1 def analysis_Bias(abf,volt,start_single,end_single,timeStart=0, timeEnd = None):
# ----> 2     abf.setSweep(0,channel=4)
#       3     bias = np.digitize(abf.sweepY[timeStart:timeEnd],bins = [(volt-100)/2])
#       4     if volt<100:
#       5         bias = 1-bias
#
# ~\anaconda3\envs\pytorch\lib\site-packages\pyabf\abf.py in setSweep(self, sweepNumber, channel, absoluteTime, baseline)
#     649         # load the actual sweep data
#     650         self.sweepY = self.data[channel, pointStart:pointEnd]
# --> 651         self.sweepX = np.arange(len(self.sweepY))*self.dataSecPerPoint
#     652         if absoluteTime:
#     653             if isFixedLengthSweeps:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Test 03_v3--Check Total Points Collected in each (x,y)

# %%
print_points_qty(abf,end_index)
# Out:
#   0. 14 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 Row Dimension:50 ; Row Total: 602
#   1. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#   2. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#   3. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#   4. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#   5. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#   6. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#   7. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#   8. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#   9. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  10. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  11. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  12. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  13. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  14. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  15. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  16. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  17. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  18. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  19. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  20. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  21. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  22. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  23. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  24. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  25. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  26. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  27. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  28. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  29. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  30. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  31. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  32. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  33. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  34. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  35. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  36. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  37. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  38. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  39. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  40. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  41. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  42. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  43. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  44. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  45. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  46. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  47. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  48. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  49. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  50. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  51. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  52. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  53. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  54. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  55. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  56. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  57. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  58. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  59. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  60. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  61. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  62. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  63. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  64. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  65. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  66. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  67. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  68. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  69. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  70. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  71. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  72. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  73. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  74. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  75. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  76. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  77. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  78. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  79. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  80. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  81. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  82. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  83. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  84. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  85. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  86. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  87. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  88. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  89. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  90. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  91. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  92. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  93. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  94. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  95. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  96. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  97. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  98. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
#  99. 7  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  Row Dimension:50 ; Row Total: 105
# 100. 12 Row Dimension:1 ; Row Total: 12
# Total points: 11009
